# %%
import os
from rich import print
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

load_dotenv(override=True)

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

OPENAI_BASE_URL = os.getenv("OPENAI_BASE_URL")

llm_openai = ChatOpenAI(
    base_url=OPENAI_BASE_URL,
    api_key=OPENAI_API_KEY,
    model="gpt-4o-mini",
)

print(llm_openai.openai_api_base)
response = llm_openai.invoke("show me what you got in one sentence")
print(response)
# Out:
# http://gpt-proxy.jd.com/v1
# AIMessage(
#     content="I'm here to provide information, answer questions, and assist with a variety of topics to help you
# find what you need!",
#     additional_kwargs={'refusal': None},
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 25,
#             'prompt_tokens': 15,
#             'total_tokens': 40,
#             'completion_tokens_details': {
#                 'accepted_prediction_tokens': 0,
#                 'audio_tokens': 0,
#                 'reasoning_tokens': 0,
#                 'rejected_prediction_tokens': 0
#             },
#             'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0},
#             'latency_checkpoint': {
#                 'engine_ttft_ms': 33,
#                 'service_ttft_ms': 425,
#                 'pre_inference_ms': 238,
#                 'total_duration_ms': 374,
#                 'engine_tbt_ms': 7,
#                 'service_tbt_ms': 8,
# ...

# %%
import os

from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
from langchain_deepseek import ChatDeepSeek
from langchain_openai import ChatOpenAI
from langchain_openrouter import ChatOpenRouter

load_dotenv(override=True)

DEEPSEEK_API_BASE = os.getenv("DEEPSEEK_API_BASE")
DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")

llm_deepseek = ChatDeepSeek(
    api_base=DEEPSEEK_API_BASE,
    api_key=DEEPSEEK_API_KEY,
    model="deepseek-v4-flash",
)

response = llm_deepseek.invoke("show me what you got in one sentence")
print(response.content)

# %%
from langchain_community.chat_models import ChatZhipuAI
import os

from dotenv import load_dotenv

load_dotenv(override=True)

ZHIPUAI_BASE_URL = os.getenv("ZHIPUAI_BASE_URL")
ZHIPUAI_API_KEY = os.getenv("ZHIPUAI_API_KEY")

llm_zhipuai = ChatZhipuAI(
    api_base=ZHIPUAI_BASE_URL,
    api_key=ZHIPUAI_API_KEY,
    model="GLM-4.7-Flash",
)

response = llm_zhipuai.invoke("show me what you got in one sentence")
print(response.content)

# %%
from langchain_community.chat_models import ChatTongyi
import os

from dotenv import load_dotenv

load_dotenv(override=True)

DASHSCOPE_API_KEY = os.getenv("DASHSCOPE_API_KEY")

llm_tongyi = ChatTongyi(
    api_key=DASHSCOPE_API_KEY,
    model="qwen3.7-max-2026-05-20",
)

response = llm_tongyi.invoke("show me what you got in one sentence")
print(response.content)

# %%
import os
from langchain_openai import ChatOpenAI

from dotenv import load_dotenv

load_dotenv(override=True)

OPENAI_BASE_URL = "https://open.bigmodel.cn/api/paas/v4"
OPENAI_API_KEY = os.getenv("ZHIPUAI_API_KEY")

llm_chatopenai = ChatOpenAI(
    base_url=OPENAI_BASE_URL,
    api_key=OPENAI_API_KEY,
    model="GLM-4.7-Flash",
)

response = llm_chatopenai.invoke("show me what you got in one sentence")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[4], line 17
#      13     api_key=OPENAI_API_KEY,
#      14     model="GLM-4.7-Flash",
#      15 )
#      16
# ---> 17 response = llm_chatopenai.invoke("show me what you got in one sentence")
#      18 print(response.content)
#      19
#
# File /opt/anaconda3/envs/langchain1.2/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:402, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     388 @override
#     389 def invoke(
#     390     self,
#    (...)    395     **kwargs: Any,
#     396 ) -> AIMessage:
#     397     config = ensure_config(config)
#     398     return cast(
#     399         "AIMessage",
#     400         cast(
#     401             "ChatGeneration",
# --> 402             self.generate_prompt(
#     403                 [self._convert_input(input)],
# ...

# %%
import os
from langchain_openrouter import ChatOpenRouter

from dotenv import load_dotenv

load_dotenv(override=True)

OPENROUTER_API_BASE = os.getenv("OPENROUTER_API_BASE")
OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")

llm_chatopenai = ChatOpenRouter(
    base_url=OPENROUTER_API_BASE,
    api_key=OPENROUTER_API_KEY,
    model="openai/gpt-oss-20b:free",
)

response = llm_chatopenai.invoke("show me what you got in one sentence")
print(response.content)

# %%
import os
from langchain.chat_models import init_chat_model

from dotenv import load_dotenv

load_dotenv(override=True)

DEEPSEEK_API_BASE = os.getenv("DEEPSEEK_API_BASE")
DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")

llm_chatopenai = init_chat_model(
    model_provider="deepseek",
    base_url=DEEPSEEK_API_BASE,
    api_key=DEEPSEEK_API_KEY,
    model="deepseek-v4-flash",
    temperature=2.0,
)

response = llm_chatopenai.invoke("show me what you got in one sentence")
print(response.content)

# %%
from langchain_ollama import ChatOllama
import os

from dotenv import load_dotenv

load_dotenv(override=True)

llm_ollama = ChatOllama(
    base_url="http://localhost:11434",
    model="deepseek-coder-v2:16b",
)

response = llm_ollama.invoke("show me what you got in one sentence")
print(response.content)

# %%
import os
from langchain.chat_models import init_chat_model

from dotenv import load_dotenv

load_dotenv(override=True)

llm_chatopenai = init_chat_model(
    model_provider="ollama",
    base_url="http://localhost:11434",
    model="deepseek-coder-v2:16b",
    temperature=2.0,
)

response = llm_chatopenai.invoke("show me what you got in one sentence")
print(response.content)
